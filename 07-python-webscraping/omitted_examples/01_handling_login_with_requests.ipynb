# %%
import requests
import bs4
import pandas as pd

# %% [markdown]
# Let's try opening a page for which we ususally have to login first.

# %%
response = requests.get("https://opensource-demo.orangehrmlive.com/index.php/recruitment/viewCandidates")
response.status_code
# Out:
# 200

# %%
soup = bs4.BeautifulSoup(response.content)
soup.find("table", id="resultTable")

# %%
with open("without_login.html", "wb") as file:
    file.write(response.content)

# %% [markdown]
# No success. We are redirected to the login page.

# %% [markdown]
# By inspecting the POST request when loggin in we find the URL and the necessary payload (`txtUsername` and `txtPassword`). Let's try logging in using it!

# %%
data = {
    "txtUsername": "Admin",
    "txtPassword": "admin123"
}
login_response = requests.post(
    "https://opensource-demo.orangehrmlive.com/index.php/auth/validateCredentials",
    data=data
)
login_response.status_code
# Out:
# 400

# %%
with open("after_login.html", "wb") as file:
    file.write(login_response.content)

# %% [markdown]
# Again, no success. The reason is that we did not send the session-specific [csrf token](https://en.wikipedia.org/wiki/Cross-site_request_forgery). It's basically a string that the server sends to us when GETting the login page and expects us to send when POSTing our login information.
#
# In order to properly handle this issue, we need to somehow connect our subsequent requests. For this we use a `session`. This allows the server to know that subsequent requests belong together, and allows us to store cookies that may be required for remaining logged in.

# %%
session = requests.Session()

login_page = session.get("https://opensource-demo.orangehrmlive.com")
login_soup = bs4.BeautifulSoup(login_page.content)
csrf_token = login_soup.find("input", type="hidden", id="csrf_token")["value"]

login_data = {
    "txtUsername": "Admin",
    "txtPassword": "admin123",
    "_csrf_token": csrf_token
}
new_login_response = session.post("https://opensource-demo.orangehrmlive.com/index.php/auth/validateCredentials",
                                  data=login_data)

# %%
with open("after_login_new.html", "wb") as file:
    file.write(new_login_response.content)

# %% [markdown]
# Logging in works now. Using the logged-in session we can now navigate to the page we originally wanted to.

# %%
candidates_response = session.get("https://opensource-demo.orangehrmlive.com/index.php/recruitment/viewCandidates")
candidates_soup = bs4.BeautifulSoup(candidates_response.content)

# %% [markdown]
# And download the data as usual.

# %%
candidates_soup.find("table", id="resultTable")
# Out:
# <table class="table hover" id="resultTable">
# <thead>
# <tr><th class="checkbox-col" rowspan="1"><input id="ohrmList_chkSelectAll" name="chkSelectAll" type="checkbox" value=""/></th>
# <th class="header" rowspan="1" style="width:"><a class="null" href="https://opensource-demo.orangehrmlive.com/index.php/recruitment/viewCandidates?sortField=jv.name&amp;sortOrder=ASC">Vacancy</a></th>
# <th class="header" rowspan="1" style="width:"><a class="null" href="https://opensource-demo.orangehrmlive.com/index.php/recruitment/viewCandidates?sortField=jc.first_name&amp;sortOrder=ASC">Candidate</a></th>
# <th class="header" rowspan="1" style="width:"><a class="null" href="https://opensource-demo.orangehrmlive.com/index.php/recruitment/viewCandidates?sortField=e.emp_firstname&amp;sortOrder=ASC">Hiring Manager</a></th>
# <th class="header" rowspan="1" style="width:"><a class="null" href="https://opensource-demo.orangehrmlive.com/index.php/recruitment/viewCandidates?sortField=jc.date_of_application&amp;sortOrder=ASC">Date of Application</a></th>
# <th class="header" rowspan="1" style="width:"><a class="null" href="https://opensource-demo.orangehrmlive.com/index.php/recruitment/viewCandidates?sortField=jcv.status&amp;sortOrder=ASC">Status</a></th>
# <th rowspan="1" style="width:"><span class="headerCell">Resume</span></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><input id="ohrmList_chkSelectRecord_37_4" name="chkSelectRow[]" type="checkbox" value="37_4"/></td> <td class="left">Associate IT Manager</td>
# <td class="left"><a href="addCandidate?id=37">Banda Pavithra R</a></td>
# <td class="left">Odis  Adalwin</td>
# <td class="left">2021-09-14</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=35">Download</a></td>
# </tr>
# <tr class="even">
# <td><input id="ohrmList_chkSelectRecord_36_4" name="chkSelectRow[]" type="checkbox" value="36_4"/></td> <td class="left">Associate IT Manager</td>
# <td class="left"><a href="addCandidate?id=36">Banda Pavithra R</a></td>
# <td class="left">Odis  Adalwin</td>
# <td class="left">2021-09-14</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=34">Download</a></td>
# </tr>
# <tr class="odd">
# <td><input id="ohrmList_chkSelectRecord_38_4" name="chkSelectRow[]" type="checkbox" value="38_4"/></td> <td class="left">Associate IT Manager</td>
# <td class="left"><a href="addCandidate?id=38">Banda Pavithra R</a></td>
# <td class="left">Odis  Adalwin</td>
# <td class="left">2021-09-14</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=36">Download</a></td>
# </tr>
# <tr class="even">
# <td><input id="ohrmList_chkSelectRecord_39_4" name="chkSelectRow[]" type="checkbox" value="39_4"/></td> <td class="left">Associate IT Manager</td>
# <td class="left"><a href="addCandidate?id=39">pavitra B R</a></td>
# <td class="left">Odis  Adalwin</td>
# <td class="left">2021-09-14</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=37">Download</a></td>
# </tr>
# <tr class="odd">
# <td><input id="ohrmList_chkSelectRecord_33_5" name="chkSelectRow[]" type="checkbox" value="33_5"/></td> <td class="left">Junior Account Assistant</td>
# <td class="left"><a href="addCandidate?id=33">maren ibis salamo</a></td>
# <td class="left">Kevin  Mathews</td>
# <td class="left">2021-09-14</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=31">Download</a></td>
# </tr>
# <tr class="even">
# <td><input id="ohrmList_chkSelectRecord_19_1" name="chkSelectRow[]" type="checkbox" value="19_1"/></td> <td class="left">Software Engineer</td>
# <td class="left"><a href="addCandidate?id=19">Jennifer  Clinton</a></td>
# <td class="left">Odis  Adalwin</td>
# <td class="left">2020-10-08</td>
# <td class="left">Rejected</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=19">Download</a></td>
# </tr>
# <tr class="odd">
# <td><input id="ohrmList_chkSelectRecord_2_2" name="chkSelectRow[]" type="checkbox" value="2_2"/></td> <td class="left">Sales Representative</td>
# <td class="left"><a href="addCandidate?id=2">Jo  Denton</a></td>
# <td class="left">Linda Jane Anderson</td>
# <td class="left">2020-10-08</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=2">Download</a></td>
# </tr>
# <tr class="even">
# <td><input id="ohrmList_chkSelectRecord_5_2" name="chkSelectRow[]" type="checkbox" value="5_2"/></td> <td class="left">Sales Representative</td>
# <td class="left"><a href="addCandidate?id=5">Charles  Haywire</a></td>
# <td class="left">Linda Jane Anderson</td>
# <td class="left">2020-10-08</td>
# <td class="left">Shortlisted</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=5">Download</a></td>
# </tr>
# <tr class="odd">
# <td><input id="ohrmList_chkSelectRecord_3_2" name="chkSelectRow[]" type="checkbox" value="3_2"/></td> <td class="left">Sales Representative</td>
# <td class="left"><a href="addCandidate?id=3">Richard  Holmes</a></td>
# <td class="left">Linda Jane Anderson</td>
# <td class="left">2020-10-08</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=3">Download</a></td>
# </tr>
# <tr class="even">
# <td><input id="ohrmList_chkSelectRecord_20_1" name="chkSelectRow[]" type="checkbox" value="20_1"/></td> <td class="left">Software Engineer</td>
# <td class="left"><a href="addCandidate?id=20">Phil  Hughes</a></td>
# <td class="left">Odis  Adalwin</td>
# <td class="left">2020-10-08</td>
# <td class="left">Shortlisted</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=20">Download</a></td>
# </tr>
# <tr class="odd">
# <td><input id="ohrmList_chkSelectRecord_18_1" name="chkSelectRow[]" type="checkbox" value="18_1"/></td> <td class="left">Software Engineer</td>
# <td class="left"><a href="addCandidate?id=18">Andrew  Keller</a></td>
# <td class="left">Odis  Adalwin</td>
# <td class="left">2020-10-08</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=18">Download</a></td>
# </tr>
# <tr class="even">
# <td><input id="ohrmList_chkSelectRecord_9_4" name="chkSelectRow[]" type="checkbox" value="9_4"/></td> <td class="left">Associate IT Manager</td>
# <td class="left"><a href="addCandidate?id=9">Joshua  Malfoy</a></td>
# <td class="left">Odis  Adalwin</td>
# <td class="left">2020-10-08</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=9">Download</a></td>
# </tr>
# <tr class="odd">
# <td><input id="ohrmList_chkSelectRecord_22_3" name="chkSelectRow[]" type="checkbox" value="22_3"/></td> <td class="left">Payroll Administrator</td>
# <td class="left"><a href="addCandidate?id=22">Muhammed  Nabeel</a></td>
# <td class="left">Paul Colling Walker</td>
# <td class="left">2020-10-08</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=22">Download</a></td>
# </tr>
# <tr class="even">
# <td><input id="ohrmList_chkSelectRecord_15_7" name="chkSelectRow[]" type="checkbox" value="15_7"/></td> <td class="left">Senior Support Specialist</td>
# <td class="left"><a href="addCandidate?id=15">Daniel  Nolan</a></td>
# <td class="left">Dominic  Chase</td>
# <td class="left">2020-10-08</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=15">Download</a></td>
# </tr>
# <tr class="odd">
# <td><input id="ohrmList_chkSelectRecord_12_6" name="chkSelectRow[]" type="checkbox" value="12_6"/></td> <td class="left">Senior QA Lead</td>
# <td class="left"><a href="addCandidate?id=12">Joe  Root</a></td>
# <td class="left">Odis  Adalwin</td>
# <td class="left">2020-10-08</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=12">Download</a></td>
# </tr>
# <tr class="even">
# <td><input id="ohrmList_chkSelectRecord_8_4" name="chkSelectRow[]" type="checkbox" value="8_4"/></td> <td class="left">Associate IT Manager</td>
# <td class="left"><a href="addCandidate?id=8">Elizabeth  Scott</a></td>
# <td class="left">Odis  Adalwin</td>
# <td class="left">2020-10-08</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=8">Download</a></td>
# </tr>
# <tr class="odd">
# <td><input id="ohrmList_chkSelectRecord_4_2" name="chkSelectRow[]" type="checkbox" value="4_2"/></td> <td class="left">Sales Representative</td>
# <td class="left"><a href="addCandidate?id=4">John  Smith</a></td>
# <td class="left">Linda Jane Anderson</td>
# <td class="left">2020-10-08</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=4">Download</a></td>
# </tr>
# <tr class="even">
# <td><input id="ohrmList_chkSelectRecord_1_6" name="chkSelectRow[]" type="checkbox" value="1_6"/></td> <td class="left">Senior QA Lead</td>
# <td class="left"><a href="addCandidate?id=1">Peter  Smith</a></td>
# <td class="left">Odis  Adalwin</td>
# <td class="left">2020-10-08</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=1">Download</a></td>
# </tr>
# <tr class="odd">
# <td><input id="ohrmList_chkSelectRecord_13_6" name="chkSelectRow[]" type="checkbox" value="13_6"/></td> <td class="left">Senior QA Lead</td>
# <td class="left"><a href="addCandidate?id=13">Martine  Tennat</a></td>
# <td class="left">Odis  Adalwin</td>
# <td class="left">2020-10-08</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=13">Download</a></td>
# </tr>
# <tr class="even">
# <td><input id="ohrmList_chkSelectRecord_11_6" name="chkSelectRow[]" type="checkbox" value="11_6"/></td> <td class="left">Senior QA Lead</td>
# <td class="left"><a href="addCandidate?id=11">Garry  White</a></td>
# <td class="left">Odis  Adalwin</td>
# <td class="left">2020-10-08</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=11">Download</a></td>
# </tr>
# <tr class="odd">
# <td><input id="ohrmList_chkSelectRecord_10_4" name="chkSelectRow[]" type="checkbox" value="10_4"/></td> <td class="left">Associate IT Manager</td>
# <td class="left"><a href="addCandidate?id=10">Mason  Jenson</a></td>
# <td class="left">Odis  Adalwin</td>
# <td class="left">2020-10-07</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=10">Download</a></td>
# </tr>
# <tr class="even">
# <td><input id="ohrmList_chkSelectRecord_17_7" name="chkSelectRow[]" type="checkbox" value="17_7"/></td> <td class="left">Senior Support Specialist</td>
# <td class="left"><a href="addCandidate?id=17">Chris  Harris</a></td>
# <td class="left">Dominic  Chase</td>
# <td class="left">2020-10-06</td>
# <td class="left">Application Initiated</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=17">Download</a></td>
# </tr>
# <tr class="odd">
# <td><input id="ohrmList_chkSelectRecord_14_7" name="chkSelectRow[]" type="checkbox" value="14_7"/></td> <td class="left">Senior Support Specialist</td>
# <td class="left"><a href="addCandidate?id=14">Anne  Clinton</a></td>
# <td class="left">Dominic  Chase</td>
# <td class="left">2020-10-01</td>
# <td class="left">Rejected</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=14">Download</a></td>
# </tr>
# <tr class="even">
# <td><input id="ohrmList_chkSelectRecord_16_7" name="chkSelectRow[]" type="checkbox" value="16_7"/></td> <td class="left">Senior Support Specialist</td>
# <td class="left"><a href="addCandidate?id=16">Gerad  Butler</a></td>
# <td class="left">Dominic  Chase</td>
# <td class="left">2020-09-24</td>
# <td class="left">Shortlisted</td>
# <td class="left"><a href="viewCandidateAttachment?attachId=16">Download</a></td>
# </tr>
# </tbody>
# </table>

# %%
table_head = candidates_soup.find("table", id="resultTable").find("thead")
table_body = candidates_soup.find("table", id="resultTable").find("tbody")

# %%
colnames = [col.text for col in table_head.find_all("th")]

data = []
for row in table_body.find_all("tr"):
    data.append([col.text for col in row.find_all("td")])

pd.DataFrame(data, columns=colnames)
# Out:
#                         Vacancy          Candidate       Hiring Manager  \
# 0          Associate IT Manager   Banda Pavithra R        Odis  Adalwin
# 1          Associate IT Manager   Banda Pavithra R        Odis  Adalwin
# 2          Associate IT Manager   Banda Pavithra R        Odis  Adalwin
# 3          Associate IT Manager        pavitra B R        Odis  Adalwin
# 4      Junior Account Assistant  maren ibis salamo       Kevin  Mathews
# 5             Software Engineer  Jennifer  Clinton        Odis  Adalwin
# 6          Sales Representative         Jo  Denton  Linda Jane Anderson
# 7          Sales Representative   Charles  Haywire  Linda Jane Anderson
# 8          Sales Representative    Richard  Holmes  Linda Jane Anderson
# 9             Software Engineer       Phil  Hughes        Odis  Adalwin
# 10            Software Engineer     Andrew  Keller        Odis  Adalwin
# 11         Associate IT Manager     Joshua  Malfoy        Odis  Adalwin
# 12        Payroll Administrator   Muhammed  Nabeel  Paul Colling Walker
# 13    Senior Support Specialist      Daniel  Nolan       Dominic  Chase
# 14               Senior QA Lead          Joe  Root        Odis  Adalwin
# 15         Associate IT Manager   Elizabeth  Scott        Odis  Adalwin
# 16         Sales Representative        John  Smith  Linda Jane Anderson
# 17               Senior QA Lead       Peter  Smith        Odis  Adalwin
# 18               Senior QA Lead    Martine  Tennat        Odis  Adalwin
# 19               Senior QA Lead       Garry  White        Odis  Adalwin
# 20         Associate IT Manager      Mason  Jenson        Odis  Adalwin
# 21    Senior Support Specialist      Chris  Harris       Dominic  Chase
# 22    Senior Support Specialist      Anne  Clinton       Dominic  Chase
# 23    Senior Support Specialist      Gerad  Butler       Dominic  Chase
#
#    Date of Application                 Status    Resume
# 0           2021-09-14  Application Initiated  Download
# 1           2021-09-14  Application Initiated  Download
# 2           2021-09-14  Application Initiated  Download
# 3           2021-09-14  Application Initiated  Download
# 4           2021-09-14  Application Initiated  Download
# 5           2020-10-08               Rejected  Download
# 6           2020-10-08  Application Initiated  Download
# 7           2020-10-08            Shortlisted  Download
# 8           2020-10-08  Application Initiated  Download
# 9           2020-10-08            Shortlisted  Download
# 10          2020-10-08  Application Initiated  Download
# 11          2020-10-08  Application Initiated  Download
# 12          2020-10-08  Application Initiated  Download
# 13          2020-10-08  Application Initiated  Download
# 14          2020-10-08  Application Initiated  Download
# 15          2020-10-08  Application Initiated  Download
# 16          2020-10-08  Application Initiated  Download
# 17          2020-10-08  Application Initiated  Download
# 18          2020-10-08  Application Initiated  Download
# 19          2020-10-08  Application Initiated  Download
# 20          2020-10-07  Application Initiated  Download
# 21          2020-10-06  Application Initiated  Download
# 22          2020-10-01               Rejected  Download
# 23          2020-09-24            Shortlisted  Download
